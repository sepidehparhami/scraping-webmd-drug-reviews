# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data
dataset_path = '/kaggle/input/psychiatric-drug-webmd-reviews/'

reviews_file = dataset_path + 'psychiatric_drug_webmd_reviews.csv'
df = pd.read_csv(reviews_file, index_col=0)

col_descripts_file = dataset_path + 'column_descriptions.csv'
col_descripts = pd.read_csv(col_descripts_file)

# %%
# description of columns

from pandas import option_context
from IPython.display import display

with option_context('display.max_colwidth', None, 'display.colheader_justify', 'left'):
    to_display = col_descripts.style.set_properties(**{'text-align': 'left'})
    display(to_display)
# Out:
# <style type="text/css">
# #T_5552a_row0_col0, #T_5552a_row0_col1, #T_5552a_row1_col0, #T_5552a_row1_col1, #T_5552a_row2_col0, #T_5552a_row2_col1, #T_5552a_row3_col0, #T_5552a_row3_col1, #T_5552a_row4_col0, #T_5552a_row4_col1, #T_5552a_row5_col0, #T_5552a_row5_col1, #T_5552a_row6_col0, #T_5552a_row6_col1, #T_5552a_row7_col0, #T_5552a_row7_col1, #T_5552a_row8_col0, #T_5552a_row8_col1, #T_5552a_row9_col0, #T_5552a_row9_col1, #T_5552a_row10_col0, #T_5552a_row10_col1, #T_5552a_row11_col0, #T_5552a_row11_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_5552a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5552a_level0_col0" class="col_heading level0 col0" >column_name</th>
#       <th id="T_5552a_level0_col1" class="col_heading level0 col1" >description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5552a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5552a_row0_col0" class="data row0 col0" >drug_name</td>
#       <td id="T_5552a_row0_col1" class="data row0 col1" >Name of medication being reviewed</td>
#     </tr>
#     <tr>
#       <th id="T_5552a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5552a_row1_col0" class="data row1 col0" >date</td>
#       <td id="T_5552a_row1_col1" class="data row1 col1" >Date of review</td>
#     </tr>
#     <tr>
#       <th id="T_5552a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5552a_row2_col0" class="data row2 col0" >age</td>
#       <td id="T_5552a_row2_col1" class="data row2 col1" >Age group of patient, selected from a dropdown list</td>
#     </tr>
#     <tr>
#       <th id="T_5552a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5552a_row3_col0" class="data row3 col0" >gender</td>
#       <td id="T_5552a_row3_col1" class="data row3 col1" >Gender of patient, selected from a dropdown list</td>
#     </tr>
#     <tr>
#       <th id="T_5552a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5552a_row4_col0" class="data row4 col0" >time_on_drug</td>
#       <td id="T_5552a_row4_col1" class="data row4 col1" >How long the medication has been taken, selected from a dropdown list</td>
#     </tr>
#     <tr>
#       <th id="T_5552a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5552a_row5_col0" class="data row5 col0" >reviewer_type</td>
#       <td id="T_5552a_row5_col1" class="data row5 col1" >The type of person reviewing, patient or caregiver</td>
#     </tr>
#     <tr>
#       <th id="T_5552a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5552a_row6_col0" class="data row6 col0" >condition</td>
#       <td id="T_5552a_row6_col1" class="data row6 col1" >The "main reason for taking this medication," selected from a dropdown list</td>
#     </tr>
#     <tr>
#       <th id="T_5552a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5552a_row7_col0" class="data row7 col0" >rating_overall</td>
#       <td id="T_5552a_row7_col1" class="data row7 col1" >Overall rating for the drug, the average of rating_effectiveness, rating_ease_of_use, and rating_satisfaction, from 1 to 5</td>
#     </tr>
#     <tr>
#       <th id="T_5552a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5552a_row8_col0" class="data row8 col0" >rating_effectiveness</td>
#       <td id="T_5552a_row8_col1" class="data row8 col1" >Agreement with the statement "This drug has worked for me," from 1 to 5 stars</td>
#     </tr>
#     <tr>
#       <th id="T_5552a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5552a_row9_col0" class="data row9 col0" >rating_ease_of_use</td>
#       <td id="T_5552a_row9_col1" class="data row9 col1" >Agreement with the statement "This medication has been easy for me to use," from 1 to 5 stars</td>
#     </tr>
#     <tr>
#       <th id="T_5552a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5552a_row10_col0" class="data row10 col0" >rating_satisfaction</td>
#       <td id="T_5552a_row10_col1" class="data row10 col1" >Agreement with the statement "Overall, I have been satisfied with my experience," from 1 to 5 stars</td>
#     </tr>
#     <tr>
#       <th id="T_5552a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5552a_row11_col0" class="data row11 col0" >text</td>
#       <td id="T_5552a_row11_col1" class="data row11 col1" >Raw, unstructured text response to "Write a brief description of your experience with this treatment."</td>
#     </tr>
#   </tbody>
# </table>

# %%
# total number of reviews available
len(df)
# Out:
# 61320

# %%
# example of some of the records in the dataset
df.head(5)
# Out:
#          drug_name       date    age  gender            time_on_drug  \
# 0  Sertraline Oral  5/12/2024  45-54  Female  1 to less than 2 years
# 1  Sertraline Oral  4/21/2024  35-44  Female       less than 1 month
# 2  Sertraline Oral  4/16/2024  25-34  Female  2 to less than 5 years
# 3  Sertraline Oral  4/11/2024  45-54    Male       less than 1 month
# 4  Sertraline Oral   4/8/2024  13-18  Female                     NaN
#
#   reviewer_type                      condition  rating_overall  \
# 0       Patient  Posttraumatic Stress Syndrome             5.0
# 1       Patient                     Depression             1.0
# 2       Patient   Repeated Episodes of Anxiety             4.3
# 3       Patient                 Panic Disorder             1.7
# 4       Patient      Major Depressive Disorder             3.0
#
#    rating_effectiveness  rating_ease_of_use  rating_satisfaction  \
# 0                     5                   5                    5
# 1                     1                   1                    1
# 2                     4                   4                    5
# 3                     1                   3                    1
# 4                     2                   4                    3
#
#                                                 text
# 0  It's almost two years now and it has been so e...
# 1  Iv been on this 4 weeks and iv never felt so a...
# 2  Been taking sertraline for past 3 years. Had n...
# 3  Of course, take this with a pinch of salt beca...
# 4                   used for a while saw no effects.

# %%
# medications included in the dataset and links to their reviews

with option_context('display.max_colwidth', None, 'display.colheader_justify', 'left'):
    to_display = drugs.style.set_properties(**{'text-align': 'left'})
    display(to_display)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 # medications included in the dataset and links to their reviews
#       3 with option_context('display.max_colwidth', None, 'display.colheader_justify', 'left'):
# ----> 4     to_display = drugs.style.set_properties(**{'text-align': 'left'})
#       5     display(to_display)
#
# NameError: name 'drugs' is not defined

# %%
# possible values for reviewer type: patient, caregiver, or empty
for x in pd.unique(df['reviewer_type']):
    print(x)

# %%
# count number of reviews for each drug - plot only the top n
fig, ax = plt.subplots(figsize=(15, 5))
n_top = 50
order = df['drug_name'].value_counts(ascending=False)[:50]
sns.countplot(df, x='drug_name', order=order.index)
plt.xticks(rotation=-45, ha='left')
ax.bar_label(container=ax.containers[0], labels=order, rotation=-90)
plt.title('Number of Reviews for Each Drug')
plt.ylim(0, 5500);

# %%
# number of drugs with at least n reviews
counts = df['drug_name'].value_counts()
print(f'{np.sum(counts >= 100)} drugs with at least 100 reviews')
print(f'{np.sum(counts >= 50)} drugs with at least 50 reviews')

# %%
bins = 10
bin_width = (5-1)/bins
ax = sns.displot(df, x='rating_overall', bins=bins)
plt.xticks(np.arange(1, 5+bin_width, bin_width));

# %%
sns.displot(df, x='rating_effectiveness', bins=5);

# %%
sns.displot(df, x='rating_ease_of_use', bins=5);

# %%
sns.displot(df, x='rating_satisfaction', bins=5)

# %%
vals = np.array([x for x in pd.unique(df['age']) if type(x)==str])
first_numbers = [int(x.split('-')[0]) for x in vals]
order_inds = np.argsort(first_numbers)
order = vals[order_inds]
sns.countplot(df, x='age', order=order)

# %%
fig, ax = plt.subplots(figsize=(15, 5))
order = df['condition'].value_counts(ascending=False)
top_n = 15
top_conds = order[:top_n].index
sns.countplot(df[[x in top_conds for x in df['condition']]], x='condition', order=top_conds)
plt.xticks(rotation=-45, ha='left');

# %% [markdown]
# ## Suggestions for Data Cleaning

# %%
# identify entries with NAs and remove or interpolate values depending on the analysis that you are doing
df.isna().sum()

# %%
# inspect the records where patient is very young
# it is possible that some of these are user input errors
# but there are also entries where age, time on drug, and reviewer type are consistent
df[[x == '0-2' for x in df['age']]]

# %%
df[[x == '3-6' for x in df['age']]]

# %%
# drop NAs

# %%
# identify nonsense reviews - for example, discard reviews where > a certain percentage of words are misspelled
